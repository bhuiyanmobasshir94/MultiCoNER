# %% [markdown]
# <a href="https://colab.research.google.com/github/bhuiyanmobasshir94/MultiCoNER/blob/main/notebooks/multiconer_baseline_000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !git clone https://github.com/amzn/multiconer-baseline
# Out:
# Cloning into 'multiconer-baseline'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 64 (delta 28), reused 40 (delta 15), pack-reused 0
# Unpacking objects: 100% (64/64), done.

# %%
# !pip install gdown
# !gdown --id 1AaaFcJ0Zzxr-fnlhlbp8mQePU6o8dFvk
# !unzip -u "./BN_DATASET.zip" -d "./multiconer-baseline/data"
# !rm -f "./BN_DATASET.zip"
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1AaaFcJ0Zzxr-fnlhlbp8mQePU6o8dFvk
# To: /content/BN_DATASET.zip
# 100% 1.38M/1.38M [00:00<00:00, 44.1MB/s]
# Archive:  ./BN_DATASET.zip
#    creating: ./multiconer-baseline/data/BN-Bangla/
#   inflating: ./multiconer-baseline/data/BN-Bangla/bn_dev.conll
#   inflating: ./multiconer-baseline/data/BN-Bangla/bn_train.conll

# %%
# !pip install virtualenv
# !virtualenv testENV2
# Out:
# ...
#      |████████████████████████████████| 6.5 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 461 kB 49.2 MB/s
# ...
# created virtual environment CPython3.7.12.final.0-64 in 857ms
#   creator CPython3Posix(dest=/content/testENV2, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==21.3.1, setuptools==60.2.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source /content/testENV2/bin/activate; pip install transformers==4.12.3 allennlp==2.8.0 pytorch-lightning==1.3.8
# Out:
# ...
#      |████████████████████████████████| 3.1 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 738 kB 47.2 MB/s
# ...
#      |████████████████████████████████| 813 kB 47.0 MB/s
# ...
#      |████████████████████████████████| 749 kB 47.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 46.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 61 kB 505 kB/s
# ...
#      |████████████████████████████████| 76 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 46.1 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 41.2 MB/s
# ...
#      |████████████████████████████████| 40 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 47.6 MB/s
# ...
#      |████████████████████████████████| 280 kB 52.0 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 49.5 MB/s
# ...

# %%
# !source /content/testENV2/bin/activate; pip list

# %%
# %cd "./multiconer-baseline"
# Out:
# /content/multiconer-baseline

# %%
# !source /content/testENV2/bin/activate; python train_model.py  --train ./data/BN-Bangla/bn_train.conll --dev ./data/BN-Bangla/bn_dev.conll --out_dir ./output-train --model_name xlmr_ner --gpus 1 --epochs 10 --encoder_model xlm-roberta-base --batch_size 64 --lr 0.0001

# %%
# !source /content/testENV2/bin/activate; python train_model.py  --train ./data/BN-Bangla/bn_train.conll --dev ./data/BN-Bangla/bn_dev.conll --out_dir ./indic_train --model_name indic_ner_bn --gpus 1 --epochs 10 --encoder_model neuralspace-reverie/indic-transformers-bn-bert --batch_size 64 --lr 0.0001
# Out:
# Downloading: 100% 488/488 [00:00<00:00, 430kB/s]
# Downloading: 100% 1.82M/1.82M [00:00<00:00, 9.57MB/s]
# 2022-01-08 17:54:12 - INFO - reader - Reading file ./data/BN-Bangla/bn_train.conll
# 2022-01-08 17:54:59 - INFO - reader - Finished reading 15300 instances from file ./data/BN-Bangla/bn_train.conll
# 2022-01-08 17:55:01 - INFO - reader - Reading file ./data/BN-Bangla/bn_dev.conll
# 2022-01-08 17:55:04 - INFO - reader - Finished reading 800 instances from file ./data/BN-Bangla/bn_dev.conll
# Downloading: 100% 516M/516M [00:12<00:00, 41.8MB/s]
# Some weights of the model checkpoint at neuralspace-reverie/indic-transformers-bn-bert were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias']
# ...

# %%
# !source /content/testENV2/bin/activate; python evaluate.py --test ./data/BN-Bangla/bn_dev.conll --out_dir . --gpus 1 --encoder_model neuralspace-reverie/indic-transformers-bn-bert \
                                --model ./indic_train/indic_ner_bn/lightning_logs/version_0/checkpoints/ --prefix indic_ner_results
# Out:
# 2022-01-08 18:19:24 - INFO - reader - Reading file ./data/BN-Bangla/bn_dev.conll
# 2022-01-08 18:19:26 - INFO - reader - Finished reading 800 instances from file ./data/BN-Bangla/bn_dev.conll
# Some weights of the model checkpoint at neuralspace-reverie/indic-transformers-bn-bert were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...
